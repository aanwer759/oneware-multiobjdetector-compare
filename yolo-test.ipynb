# %%
from ultralytics import YOLO

# %%
model = YOLO("fruits-weight/yolov11n-custom/YOLOv11n-custom-20250111-2.pt")

# %%
source = "images/3.jpg"
result = model(source, save=True)
# Out:
# image 1/1 e:\object-detectors-comparision (oneware)\images\3.jpg: 384x640 6 not strawberrys, 250.1ms
# Speed: 0.8ms preprocess, 250.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict5
