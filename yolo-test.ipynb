# %%
from ultralytics import YOLO

# %%
model = YOLO("fruits-weight/yolov11m-custom/yolov11-custom.pt")

source = "dataset/only_strawberries_yolo-dataset/1.jpg"
source2 = "images/strawberry.jpeg"

# %%
result = model(source, save=True)
# Out:
# image 1/1 e:\object-detectors-comparision (oneware)\dataset\only_strawberries_yolo-dataset\1.jpg: 384x640 3 strawberrys, 210.3ms
# Speed: 2.0ms preprocess, 210.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict3
